# %%
import pandas as pd
import numpy as np
import folium

# %%
path2="https://raw.githubusercontent.com/deepakkapse/viola/master/hospitalcsv.csv"

# %%
df1=pd.read_csv(path2)

# %%
india=(20.5937,78.9629)

# %% [markdown]
# # Hospitals Treating corona in India

# %%
from folium import plugins

# let's start again with a clean copy of the map of San Francisco
hospitals = folium.Map(location=india, zoom_start = 4, tiles='Stamen Terrain')

# instantiate a mark cluster object for the incidents in the dataframe
incidents = plugins.MarkerCluster().add_to(hospitals)

# loop through the dataframe and add each data point to the mark cluster
for lat,lng,hosp  in zip(df1["Latitude"], df1["Longitude"], df1["hospital"]):
    folium.Marker(
        location=[lat, lng],
        icon=None,
        popup=("Hospital:"+str(hosp)),
    ).add_to(incidents)

# display map
hospitals
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
path="https://raw.githubusercontent.com/Adityanagraj/viola/master/complete.csv"

# %%
df=pd.read_csv(path)

# %%
df["pickdate"] = pd.to_datetime(df.Date, format='%Y-%m-%d')

# %%
def generateBaseMap(default_location=[20.5937, 78.9629], default_zoom_start=4):
    base_map = folium.Map(location=default_location, control_scale=True, zoom_start=default_zoom_start)
    return base_map

# %%
base_map=generateBaseMap()

# %% [markdown]
# # Displaying The dense of CovidCases affected Area during initial days in India

# %%
from folium.plugins import HeatMap
#df_copy = df[df.month>4].copy()
#df_copy['count'] = 1
base_map = generateBaseMap()
HeatMap(data=df[['Latitude', 'Longitude']].groupby(['Latitude', 'Longitude']).sum().reset_index().values.tolist(), radius=8, max_zoom=22).add_to(base_map)
base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
